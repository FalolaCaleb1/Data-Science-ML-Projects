# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:/Users/Dell/Downloads/diagonized.csv')

# %%
data
# Out:
#         WBC    LYMp   NEUTp     LYMn    NEUTn   RBC   HGB       HCT   MCV  \
# 0     10.00  43.200  50.100  4.30000  5.00000  2.77   7.3   24.2000  87.7
# 1     10.00  42.400  52.300  4.20000  5.30000  2.84   7.3   25.0000  88.2
# 2      7.20  30.700  60.700  2.20000  4.40000  3.97   9.0   30.5000  77.0
# 3      6.00  30.200  63.500  1.80000  3.80000  4.22   3.8   32.8000  77.9
# 4      4.20  39.100  53.700  1.60000  2.30000  3.93   0.4  316.0000  80.6
# ...     ...     ...     ...      ...      ...   ...   ...       ...   ...
# 1276   4.40  25.845  77.511  1.88076  5.14094  4.86  13.5   46.1526  80.7
# 1277   5.60  25.845  77.511  1.88076  5.14094  4.85  15.0   46.1526  91.7
# 1278   9.20  25.845  77.511  1.88076  5.14094  4.47  13.1   46.1526  88.7
# 1279   6.48  25.845  77.511  1.88076  5.14094  4.75  13.2   46.1526  86.7
# 1280   8.80  25.845  77.511  1.88076  5.14094  4.95  15.2   46.1526  89.7
#
#        MCH  MCHC    PLT        PDW      PCT                      Diagnosis
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1281 entries, 0 to 1280
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   WBC        1281 non-null   float64
#  1   LYMp       1281 non-null   float64
#  2   NEUTp      1281 non-null   float64
#  3   LYMn       1281 non-null   float64
#  4   NEUTn      1281 non-null   float64
#  5   RBC        1281 non-null   float64
#  6   HGB        1281 non-null   float64
#  7   HCT        1281 non-null   float64
#  8   MCV        1281 non-null   float64
#  9   MCH        1281 non-null   float64
#  10  MCHC       1281 non-null   float64
#  11  PLT        1281 non-null   float64
#  12  PDW        1281 non-null   float64
#  13  PCT        1281 non-null   float64
#  14  Diagnosis  1281 non-null   object
# dtypes: float64(14), object(1)
# memory usage: 150.2+ KB

# %%
data.describe().T
# Out:
#         count        mean         std    min        25%         50%  \
# WBC    1281.0    7.862717    3.564466   0.80    6.00000    7.400000
# LYMp   1281.0   25.845000    7.038728   6.20   25.84500   25.845000
# NEUTp  1281.0   77.511000  147.746273   0.70   71.10000   77.511000
# LYMn   1281.0    1.880760    1.335689   0.20    1.88076    1.880760
# NEUTn  1281.0    5.140940    2.872294   0.50    5.10000    5.140940
# RBC    1281.0    4.708267    2.817200   1.36    4.19000    4.600000
# HGB    1281.0   12.184551    3.812897 -10.00   10.80000   12.300000
# HCT    1281.0   46.152600  104.886100   2.00   39.20000   46.152600
# MCV    1281.0   85.793919   27.177663 -79.30   81.20000   86.600000
# MCH    1281.0   32.084840  111.170756  10.90   25.50000   27.800000
# MCHC   1281.0   31.739149    3.300352  11.50   30.60000   32.000000
# PLT    1281.0  229.981421   93.019336  10.00  157.00000  213.000000
# PDW    1281.0   14.312512    3.005079   8.40   13.30000   14.312512
# ...

# %%
data.isnull().sum()
# Out:
# WBC          0
# LYMp         0
# NEUTp        0
# LYMn         0
# NEUTn        0
# RBC          0
# HGB          0
# HCT          0
# MCV          0
# MCH          0
# MCHC         0
# PLT          0
# PDW          0
# PCT          0
# Diagnosis    0
# dtype: int64

# %%
data['Diagnosis'].value_counts()
# Out:
# Diagnosis
# Healthy                           336
# Normocytic hypochromic anemia     279
# Normocytic normochromic anemia    269
# Iron deficiency anemia            189
# Thrombocytopenia                   73
# Other microcytic anemia            59
# Leukemia                           47
# Macrocytic anemia                  18
# Leukemia with thrombocytopenia     11
# Name: count, dtype: int64

# %%
Diagnosis  = data['Diagnosis']

# %%
data['Diagnosis'] = data['Diagnosis'].str.replace('Normocytic hypochromic anemia', 'Anemia')
data['Diagnosis'] = data['Diagnosis'].str.replace('Iron deficiency anemia', 'Anemia')
data['Diagnosis'] = data['Diagnosis'].str.replace('Normocytic normochromic anemia', 'Anemia')
data['Diagnosis'] = data['Diagnosis'].str.replace('Other microcytic anemia', 'Anemia')
data['Diagnosis'] = data['Diagnosis'].str.replace('Macrocytic anemia', 'Anemia')
data['Diagnosis'] = data['Diagnosis'].str.replace('Leukemia with thrombocytopenia', 'Leukemia')
data['Diagnosis'] = data['Diagnosis'].str.replace('Thrombocytopenia', 'Leukemia')

# %%
data['Diagnosis'].value_counts()
# Out:
# Diagnosis
# Anemia      814
# Healthy     336
# Leukemia    131
# Name: count, dtype: int64

# %%
data['Diagnosis'] = data['Diagnosis'].str.replace('Anemia', '1')
data['Diagnosis'] = data['Diagnosis'].str.replace('Healthy', '2')
data['Diagnosis'] = data['Diagnosis'].str.replace('Leukemia', '3')

# %%
data['Diagnosis'].value_counts()
# Out:
# Diagnosis
# 1    814
# 2    336
# 3    131
# Name: count, dtype: int64

# %%
data['Diagnosis'] = data['Diagnosis'].astype(int)

# %%
data.dtypes
# Out:
# WBC          float64
# LYMp         float64
# NEUTp        float64
# LYMn         float64
# NEUTn        float64
# RBC          float64
# HGB          float64
# HCT          float64
# MCV          float64
# MCH          float64
# MCHC         float64
# PLT          float64
# PDW          float64
# PCT          float64
# Diagnosis      int32
# dtype: object

# %%
data.dtypes
# Out:
# WBC          float64
# LYMp         float64
# NEUTp        float64
# LYMn         float64
# NEUTn        float64
# RBC          float64
# HGB          float64
# HCT          float64
# MCV          float64
# MCH          float64
# MCHC         float64
# PLT          float64
# PDW          float64
# PCT          float64
# Diagnosis      int32
# dtype: object

# %%
data['Diagnosis'] = data['Diagnosis'].astype('category')

# %%
data.dtypes
# Out:
# WBC           float64
# LYMp          float64
# NEUTp         float64
# LYMn          float64
# NEUTn         float64
# RBC           float64
# HGB           float64
# HCT           float64
# MCV           float64
# MCH           float64
# MCHC          float64
# PLT           float64
# PDW           float64
# PCT           float64
# Diagnosis    category
# dtype: object

# %%
data
# Out:
#         WBC    LYMp   NEUTp     LYMn    NEUTn   RBC   HGB       HCT   MCV  \
# 0     10.00  43.200  50.100  4.30000  5.00000  2.77   7.3   24.2000  87.7
# 1     10.00  42.400  52.300  4.20000  5.30000  2.84   7.3   25.0000  88.2
# 2      7.20  30.700  60.700  2.20000  4.40000  3.97   9.0   30.5000  77.0
# 3      6.00  30.200  63.500  1.80000  3.80000  4.22   3.8   32.8000  77.9
# 4      4.20  39.100  53.700  1.60000  2.30000  3.93   0.4  316.0000  80.6
# ...     ...     ...     ...      ...      ...   ...   ...       ...   ...
# 1276   4.40  25.845  77.511  1.88076  5.14094  4.86  13.5   46.1526  80.7
# 1277   5.60  25.845  77.511  1.88076  5.14094  4.85  15.0   46.1526  91.7
# 1278   9.20  25.845  77.511  1.88076  5.14094  4.47  13.1   46.1526  88.7
# 1279   6.48  25.845  77.511  1.88076  5.14094  4.75  13.2   46.1526  86.7
# 1280   8.80  25.845  77.511  1.88076  5.14094  4.95  15.2   46.1526  89.7
#
#        MCH  MCHC    PLT        PDW      PCT Diagnosis
# ...

# %%
categorical_list = []
numerical_list = []

for col in data.columns:
    if data[col].dtypes == 'category':
        data[col] = data[col].astype('category')
        categorical_list.append(col)
    else:
        numerical_list.append(col)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X = data.drop(['Diagnosis'], axis = 1)

# %%
y = data['Diagnosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
mod = LogisticRegression()

# %%
mod.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = mod.predict(X_test)

# %%
mod.score(X_test, y_test)
# Out:
# 0.838006230529595

# %%
y_pred = mod.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_test, y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.83      0.97      0.89       208
#            2       0.85      0.69      0.76        77
#            3       0.94      0.42      0.58        36
#
#     accuracy                           0.84       321
#    macro avg       0.87      0.69      0.74       321
# weighted avg       0.85      0.84      0.83       321
